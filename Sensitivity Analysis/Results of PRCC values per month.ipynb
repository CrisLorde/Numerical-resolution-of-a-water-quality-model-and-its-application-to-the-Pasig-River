# %% [markdown]
# Guadalupe Station

# %% [markdown]
# |Month|Jan|Feb|Mar|Apr|May|June|July|Aug|Sept|Oct|Nov|Dec|
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# |K |-0.29887814|0.17113695|-0.23386196| 0.06598199||-0.07391877|-0.10738113|-0.17661653|-0.22928913|0.36756615|||
# |Q1|0.84312476|0.88660157|0.86427557| 0.879435 ||0.87492185|0.82292766|0.86219962|0.86908186|0.78015654|||
# |Q2|-0.72752792|-0.84463305|-0.83039665|-0.73757032||-0.8454267|-0.80893945|-0.81907946|-0.82382894|-0.84962599|||
# |Q3|-0.46033027|-0.46200726|-0.5063664 |-0.45760695||-0.54904837|-0.50448676|-0.51384905|-0.4558396|-0.34055079|||
# |dummy|0.01561982|0.03820453|-0.05027407|0.06401883||0.00410767|-0.04590882|-0.07918182|0.08691151|-0.04295593|||

# %%
import matplotlib.pyplot as plt 
import numpy as np 
  
# create data 
x = np.arange(5) 
Jan = [-0.29887814, 0.84312476, -0.72752792, -0.46033027, 0.01561982] 
Feb = [0.17113695, 0.88660157, -0.84463305, -0.46200726, 0.03820453] 
Mar = [-0.23386196, 0.86427557, -0.83039665, -0.5063664, -0.05027407]
Apr = [0.06598199, 0.879435, -0.73757032, -0.45760695, 0.06401883]
May = [0.32905055,  0.88806554, -0.8370885,  -0.44194083,  0.02469963]
Jun = [-0.07391877, 0.87492185, -0.8454267, -0.54904837, 0.00410767] 
Jul = [-0.10738113, 0.82292766, -0.80893945, -0.50448676, -0.04590882] 
Aug = [-0.17661653, 0.86219962, -0.81907946, -0.51384905, -0.07918182] 
Sep = [-0.22928913, 0.86908186, -0.82382894, -0.4558396, 0.08691151] 
Oct = [0.36756615, 0.78015654, -0.84962599, -0.34055079, -0.04295593] 
Nov = [-0.07449619,  0.89057961, -0.79642084, -0.43586296,  0.02939678]
Dec = [ 0.27945914,  0.90377175, -0.88802121, -0.4099943,  -0.03615067]
width = 0.08

# plot data in grouped manner of bar type 
plt.bar(x-0.48, Jan, width, color='blue', label = "Jan") 
plt.bar(x-0.40, Feb, width, color='#002cf3', label = "Feb") 
plt.bar(x-0.32, Mar, width, color='#0054e8', label = "Mar")
plt.bar(x-0.24, Apr, width, color='#0078dc', label = "Apr") 
plt.bar(x-0.16, May, width, color='#0098d1', label = "May") 
plt.bar(x-0.08, Jun, width, color='#00b3c5', label = "Jun") 
plt.bar(x, Jul, width, color='#00baa9', label = "Jul")
plt.bar(x+0.08, Aug, width, color='#00ae7f', label = "Aug") 
plt.bar(x+0.16, Sep, width, color='#00a359', label = "Sep") 
plt.bar(x+0.24, Oct, width, color='#009737', label = "Oct") 
plt.bar(x+0.32, Nov, width, color='#008c19', label = "Nov") 
plt.bar(x+0.40, Dec, width, color='green', label = "Dec") 
plt.axhline(y=0, color='black', linestyle='-')


plt.xticks(x, ['K', 'Q1', 'Q2', 'Q3', 'dummy']) 
plt.xlabel("Parameters at Guadalupe") 
plt.ylabel("PRRC values") 
plt.ylim(-1, 1)
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
plt.savefig('PRCC values at x = 72.png', bbox_inches='tight') 
plt.show()

# %% [markdown]
# Lambingan Station

# %% [markdown]
# |Month|Jan|Feb|Mar|Apr|May|June|July|Aug|Sept|Oct|Nov|Dec|
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# |K |-0.07896628|-0.00126631|-0.35286848 |0.07772745||-0.2912972|-0.26937639|-0.07618128|-0.23071595|0.15711097|||
# |Q1|0.75263916|0.78695946|0.84641413|0.86931884||0.81628647|0.76809058|0.77846836|0.77836976|0.56200629|||
# |Q2|0.52733695|0.57627665| 0.68612311|0.65769853||0.63429683|0.66117937|0.6120385 |0.5299612|0.28312759 |||
# |Q3|-0.85890377|-0.81765631|-0.90189927|-0.86257301||-0.87574183|-0.85338758|-0.85924627|-0.82590806|-0.79101486|||
# |dummy|-0.01788656|-0.00496647|-0.13519493| 0.07314228||0.05249182|-0.11061842|-0.02991605|0.05435442|-0.06780539|||

# %%
import matplotlib.pyplot as plt 
import numpy as np 
  
# create data 
x = np.arange(5) 
Jan = [-0.07896628, 0.75263916, 0.52733695, -0.85890377, -0.01788656] 
Feb = [-0.00126631, 0.78695946, 0.57627665, -0.81765631, -0.00496647] 
Mar = [-0.35286848, 0.84641413, 0.68612311, -0.90189927, -0.13519493]
Apr = [0.07772745, 0.86931884, 0.65769853, -0.86257301, 0.07314228]
May = [ 0.15351173,  0.82451147,  0.60556045, -0.83884625, -0.0081774]
Jun = [-0.2912972, 0.81628647, 0.63429683, -0.87574183, 0.05249182] 
Jul = [-0.26937639, 0.76809058, 0.66117937, -0.85338758, -0.11061842] 
Aug = [-0.07618128, 0.77846836, 0.6120385, -0.85924627, -0.02991605] 
Sep = [-0.23071595, 0.77836976, 0.5299612, -0.82590806, 0.05435442] 
Oct = [0.15711097, 0.56200629, 0.28312759, -0.79101486, -0.06780539] 
Nov = [-0.0596618,   0.79079597,  0.4147956,  -0.82378313,  0.00352633]
Dec = [ 0.07045019,  0.86027406,  0.51239451, -0.86549274, -0.07796343]
width = 0.08

# plot data in grouped manner of bar type 
plt.bar(x-0.48, Jan, width, color='blue', label = "Jan") 
plt.bar(x-0.40, Feb, width, color='#002cf3', label = "Feb") 
plt.bar(x-0.32, Mar, width, color='#0054e8', label = "Mar")
plt.bar(x-0.24, Apr, width, color='#0078dc', label = "Apr") 
plt.bar(x-0.16, May, width, color='#0098d1', label = "May") 
plt.bar(x-0.08, Jun, width, color='#00b3c5', label = "Jun") 
plt.bar(x, Jul, width, color='#00baa9', label = "Jul")
plt.bar(x+0.08, Aug, width, color='#00ae7f', label = "Aug") 
plt.bar(x+0.16, Sep, width, color='#00a359', label = "Sep") 
plt.bar(x+0.24, Oct, width, color='#009737', label = "Oct") 
plt.bar(x+0.32, Nov, width, color='#008c19', label = "Nov") 
plt.bar(x+0.40, Dec, width, color='green', label = "Dec") 
plt.axhline(y=0, color='black', linestyle='-')


plt.xticks(x, ['K', 'Q1', 'Q2', 'Q3', 'dummy']) 
plt.xlabel("Parameters at Lambingan") 
plt.ylabel("PRRC values") 
plt.ylim(-1, 1)
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
plt.savefig('PRCC values at x = 170.png', bbox_inches='tight') 
plt.show()

# %%
from colour import Color
red = Color("blue")
colors = list(red.range_to(Color("green"),12))
print(colors)
# Out:
# [<Color blue>, <Color #002cf3>, <Color #0054e8>, <Color #0078dc>, <Color #0098d1>, <Color #00b3c5>, <Color #00baa9>, <Color #00ae7f>, <Color #00a359>, <Color #009737>, <Color #008c19>, <Color green>]
