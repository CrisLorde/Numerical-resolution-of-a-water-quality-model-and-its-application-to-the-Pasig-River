# %%
import matplotlib.pyplot as plt 
import numpy as np 
  
# create data 
x = np.arange(3) 
Jan = [ 1.089e+02,  1.051e+02,  8.745e+01] #implicit already
Feb = [ 7.311e+01,  1.528e+02,  9.367e+01] #implicit already
Mar = [ 5.238e+01,  1.843e+02,  9.278e+01] #implicit already
Apr = [ 1.243e+02,  2.581e+02,  2.016e+01] #nasa PC #implicit already
May = [ 1.367e+02,  1.561e+02,  2.478e+01] #implicit already
Jun = [50.221479, 208.08200566, 126.13521099] #Dell laptop #implicit already
Jul = [46.8723412, 225.4242616, 120.72917576] #Dell laptop #implicit already
Aug = [51.25050321, 169.58052467, 100.97217411] #Dell laptop #implicit already
Sep = [88.58605912, 137.8539613, 88.40498169] #Dell laptop #implicit already
Oct = [69.0623503, 137.37585116, 114.02109165] #Dell laptop #implicit already
Nov = [116.78319956, 132.09477165, 66.85641334] #Dell laptop #implicit already
Dec = [104.59625179, 148.85747373, 70.22485044] #Dell laptop #implicit already

width = 0.05

# plot data in grouped manner of bar type 
plt.bar(x-0.25, Jan, width, color='blue', label = "Jan") 
plt.bar(x-0.20, Feb, width, color='#002cf3', label = "Feb") 
plt.bar(x-0.15, Mar, width, color='#0054e8', label = "Mar")
plt.bar(x-0.10, Apr, width, color='#0078dc', label = "Apr") 
plt.bar(x-0.05, May, width, color='#0098d1', label = "May") 
plt.bar(x, Jun, width, color='#00b3c5', label = "Jun")
plt.bar(x+0.05, Jul, width, color='#00baa9', label = "Jul") 
plt.bar(x+0.10, Aug, width, color='#00ae7f', label = "Aug") 
plt.bar(x+0.15, Sep, width, color='#00a359', label = "Sep") 
plt.bar(x+0.20, Oct, width, color='#009737', label = "Oct") 
plt.bar(x+0.25, Nov, width, color='#008c19', label = "Nov") 
plt.bar(x+0.30, Nov, width, color='green', label = "Dec")
plt.axhline(y=0, color='black', linestyle='-')


plt.xticks(x, ['Bambang', 'Guadalupe', 'Lambingan']) 
plt.xlabel("Stations") 
plt.ylabel("flow rate $Q$") 
#plt.ylim(-1, 1)
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
plt.savefig('flowrate estimates 2018.png', bbox_inches='tight') 
plt.show()
