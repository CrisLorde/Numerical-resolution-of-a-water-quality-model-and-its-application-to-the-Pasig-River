# %% [markdown]
# Results of parameter estimation for K and Q with fixed initial condition.

# %% [markdown]
# |Month|Jan|Feb|Mar|Apr|May|June|July|Aug|Sept|Oct|Nov|Dec|
# |---|---|---|---|---|---|---|---|---|---|---|---|---|
# |K Value|4.996e+02|4.997e+02|4.996e+02|4.919e+02|4.989e+02|4.994e+02|5.071e+02|5.004e+02|4.996e+02|5.000e+02|4.991e+02|4.995e+02|
# |Bambang|1.082e+02|9.521e+01|8.668e+01|1.675e+02|1.601e+02|7.434e+01|8.562e+01|8.732e+01|1.053e+02|9.217e+01|1.190e+02|1.202e+02|
# |Guadalupe|1.019e+02|1.278e+02|1.436e+02|1.842e+02|1.122e+02|1.473e+02|1.673e+02|1.281e+02|1.201e+02|1.209e+02|1.167e+02|1.198e+02|
# |Lambingan|9.097e+01|8.478e+01|8.061e+01|2.573e+01|2.835e+01|9.187e+01|9.489e+01|9.156e+01|8.136e+01|9.330e+01|7.199e+01|6.788e+01|

# %%
import matplotlib.pyplot as plt 
import numpy as np 
  
# create data 
x = np.arange(3) 
Jan = [1.082e+02,1.019e+02,9.097e+01] 
Feb = [9.521e+01,1.278e+02,8.478e+01] 
Mar = [8.668e+01,1.436e+02,8.061e+01]
Apr = [1.675e+02,1.842e+02,2.573e+01]  
May = [1.601e+02,1.122e+02,2.835e+01]
Jun = [7.434e+01,1.473e+02,9.187e+01] 
Jul = [8.562e+01,1.673e+02,9.489e+01] 
Aug = [8.732e+01,1.281e+02,9.156e+01] 
Sep = [1.053e+02,1.201e+02,8.136e+01] 
Oct = [9.217e+01,1.209e+02,9.330e+01] 
Nov = [1.190e+02,1.167e+02,7.199e+01]
Dec = [1.202e+02,1.198e+02,6.788e+01]

width = 0.05

# plot data in grouped manner of bar type 
plt.bar(x-0.25, Jan, width, color='blue', label = "Jan") 
plt.bar(x-0.20, Feb, width, color='#002cf3', label = "Feb") 
plt.bar(x-0.15, Mar, width, color='#0054e8', label = "Mar")
plt.bar(x-0.10, Apr, width, color='#0078dc', label = "Apr") 
plt.bar(x-0.05, May, width, color='#0098d1', label = "May") 
plt.bar(x, Jun, width, color='#00b3c5', label = "Jun")
plt.bar(x+0.05, Jul, width, color='#00baa9', label = "Jul") 
plt.bar(x+0.10, Aug, width, color='#00ae7f', label = "Aug") 
plt.bar(x+0.15, Sep, width, color='#00a359', label = "Sep") 
plt.bar(x+0.20, Oct, width, color='#009737', label = "Oct") 
plt.bar(x+0.25, Nov, width, color='#008c19', label = "Nov") 
plt.bar(x+0.30, Nov, width, color='green', label = "Dec")
plt.axhline(y=0, color='black', linestyle='-')


plt.xticks(x, ['Bambang', 'Guadalupe', 'Lambingan']) 
plt.xlabel("Stations") 
plt.ylabel("flow rate $Q$") 
#plt.ylim(-1, 1)
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
plt.savefig('flowrate estimates 2018.png', bbox_inches='tight') 
plt.show()
