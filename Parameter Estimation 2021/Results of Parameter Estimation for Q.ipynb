# %% [markdown]
# Results of parameter estimation for K and Q with fixed initial condition.

# %% [markdown]
# |Month|K Value|Bambang|Guadalupe|Lambingan|
# |---|---|---|---|---|
# |Jan|9.999e+02|1.073e+02|1.135e+02|8.349e+01|
# |Feb|9.974e+02|3.130e+01|7.263e+01|1.805e+02|
# |Mar|1.000e+03|9.761e+01|1.377e+02|8.228e+01|
# |Apr|9.993e+02|1.161e+02|1.178e+02|7.693e+01|
# |May|1.131e+03|7.279e+02|5.355e+02|3.777e+02|
# |Jun|9.997e+02|1.278e+02|1.211e+02|6.970e+01|
# |Jul|9.993e+02|1.159e+02|1.273e+02|6.728e+01|
# |Aug|9.958e+02|8.835e+01|1.903e+02|6.918e+01|
# |Sep|9.968e+02|1.228e+02|1.627e+02|6.245e+01|
# |Oct|1.013e+03|1.154e+02|2.033e+02|1.881e+02|
# |Nov|9.932e+02|9.865e+01|2.046e+02|5.722e+01|
# |Dec|1.002e+03|1.452e+02|6.770e+01|6.569e+01|

# %%
import matplotlib.pyplot as plt 
import numpy as np 
  
# create data 
x = np.arange(3) 
Jan = [1.073e+02,1.135e+02,8.349e+01] 
Feb = [3.130e+01,7.263e+01,1.805e+02] 
Mar = [9.761e+01,1.377e+02,8.228e+01]
Apr = [1.161e+02,1.178e+02,7.693e+01]  
May = [7.279e+02,5.355e+02,3.777e+02]
Jun = [1.278e+02,1.211e+02,6.970e+01] 
Jul = [1.159e+02,1.273e+02,6.728e+01] 
Aug = [8.835e+01,1.903e+02,6.918e+01]
Sep = [1.228e+02,1.627e+02,6.245e+01] 
Oct = [1.154e+02,2.033e+02,1.881e+02] 
Nov = [9.865e+01,2.046e+02,5.722e+01]
Dec = [1.452e+02,6.770e+01,6.569e+01]

width = 0.05

# plot data in grouped manner of bar type 
plt.bar(x-0.25, Jan, width, color='blue', label = "Jan") 
plt.bar(x-0.20, Feb, width, color='#002cf3', label = "Feb") 
plt.bar(x-0.15, Mar, width, color='#0054e8', label = "Mar")
plt.bar(x-0.10, Apr, width, color='#0078dc', label = "Apr") 
plt.bar(x-0.05, May, width, color='#0098d1', label = "May") 
plt.bar(x, Jun, width, color='#00b3c5', label = "Jun")
plt.bar(x+0.05, Jul, width, color='#00baa9', label = "Jul") 
plt.bar(x+0.10, Aug, width, color='#00ae7f', label = "Aug") 
plt.bar(x+0.15, Sep, width, color='#00a359', label = "Sep") 
plt.bar(x+0.20, Oct, width, color='#009737', label = "Oct") 
plt.bar(x+0.25, Nov, width, color='#008c19', label = "Nov") 
plt.bar(x+0.30, Nov, width, color='green', label = "Dec")
plt.axhline(y=0, color='black', linestyle='-')


plt.xticks(x, ['Bambang', 'Guadalupe', 'Lambingan']) 
plt.xlabel("Stations") 
plt.ylabel("flow rate $Q$") 
#plt.ylim(-1, 1)
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
plt.savefig('flowrate estimates 2021.png', bbox_inches='tight') 
plt.show()

# %%
from colour import Color
red = Color("blue")
colors = list(red.range_to(Color("green"),12))
print(colors)
# Out:
# [<Color blue>, <Color #002cf3>, <Color #0054e8>, <Color #0078dc>, <Color #0098d1>, <Color #00b3c5>, <Color #00baa9>, <Color #00ae7f>, <Color #00a359>, <Color #009737>, <Color #008c19>, <Color green>]

# %% [markdown]
# Without K and Implicit

# %%
import matplotlib.pyplot as plt 
import numpy as np 
  
# create data 
x = np.arange(3) 
Jan = [ 1.061e+02,  1.139e+02,  8.416e+01]
Feb = [ 1.191e+02,  8.075e+01,  9.691e+01]
Mar = [ 9.493e+01,  1.387e+02,  8.062e+01]
Apr = [ 1.183e+02,  1.203e+02,  7.789e+01]  
May = [ 1.139e+02,  1.979e+02,  1.018e+02]
Jun = [ 1.232e+02,  1.176e+02,  6.741e+01] 
Jul = [ 1.158e+02,  1.297e+02,  6.844e+01] 
Aug = [ 8.234e+01,  2.082e+02,  6.631e+01] 
Sep = [ 1.146e+02,  1.722e+02,  5.723e+01] 
Oct = [ 8.158e+01,  1.762e+02,  1.541e+02] 
Nov = [ 9.693e+01,  2.137e+02,  5.619e+01]
Dec = [ 1.436e+02,  6.821e+01,  6.409e+01]

width = 0.05

# plot data in grouped manner of bar type 
plt.bar(x-0.25, Jan, width, color='blue', label = "Jan") 
plt.bar(x-0.20, Feb, width, color='#002cf3', label = "Feb") 
plt.bar(x-0.15, Mar, width, color='#0054e8', label = "Mar")
plt.bar(x-0.10, Apr, width, color='#0078dc', label = "Apr") 
plt.bar(x-0.05, May, width, color='#0098d1', label = "May") 
plt.bar(x, Jun, width, color='#00b3c5', label = "Jun")
plt.bar(x+0.05, Jul, width, color='#00baa9', label = "Jul") 
plt.bar(x+0.10, Aug, width, color='#00ae7f', label = "Aug") 
plt.bar(x+0.15, Sep, width, color='#00a359', label = "Sep") 
plt.bar(x+0.20, Oct, width, color='#009737', label = "Oct") 
plt.bar(x+0.25, Nov, width, color='#008c19', label = "Nov") 
plt.bar(x+0.30, Nov, width, color='green', label = "Dec")
plt.axhline(y=0, color='black', linestyle='-')


plt.xticks(x, ['Bambang', 'Guadalupe', 'Lambingan']) 
plt.xlabel("Stations") 
plt.ylabel("flow rate $Q$") 
#plt.ylim(-1, 1)
plt.legend(bbox_to_anchor=(1.0, 1.0), loc='upper left')
plt.savefig('flowrate estimates 2021.png', bbox_inches='tight') 
plt.show()
